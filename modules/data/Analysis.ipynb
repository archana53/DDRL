# %%
# %matplotlib inline
import matplotlib.image as mpimg
import cv2 
import matplotlib.pyplot as plt 
import random

# %%
ground_truth_file = '/home/suyash/Gatech/DDRL/modules/data/aflw_dataset/AFLW_lists/all.GTB'
with open(ground_truth_file) as file:
    ground_truths = [line.rstrip() for line in file]

# %%
def get_random_ground_truth(ground_truths):
    selected_idx = random.randint(0, len(ground_truths))
    ground_truth = ground_truths[selected_idx]
    split_line = ground_truth.split(' ')
    return split_line[0], split_line[1]

# %%
imgpath, ptspath = "/home/suyash/Gatech/DDRL/modules/data/aflw_dataset/images/3/image00168.jpg", "/home/suyash/Gatech/DDRL/modules/data/aflw_dataset/processed/annotations/3/image00168-2.pts"

# %%
imgpath, ptspath = get_random_ground_truth(ground_truths)
print(imgpath)
print(ptspath)
# Out:
# /home/suyash/Gatech/DDRL/modules/data/aflw_dataset/images/2/image31882.jpg
# /home/suyash/Gatech/DDRL/modules/data/aflw_dataset/processed/annotations/2/image31882-10705.pts

# %%
with open(ptspath) as file:
    lines = [line.rstrip() for line in file]
    
coords_x = []
coords_y = []
coords = []
for line in lines:
    split_line = line.split(' ')
    coords_x.append(split_line[1])
    coords_y.append(split_line[2])
    coords.append((split_line[1], split_line[2]))

# %%
coords
# Out:
# [('127.52', '71.14'),
#  ('142.16', '77.09'),
#  ('154.06', '82.80'),
#  ('166.95', '87.51'),
#  ('173.90', '87.76'),
#  ('134.72', '86.02'),
#  ('141.66', '87.76'),
#  ('129.76', '109.83'),
#  ('149.09', '118.60'),
#  ('116.37', '126.69'),
#  ('132.73', '136.86'),
#  ('120.00', '156.00')]

# %%
keypoints = [cv2.KeyPoint(float(x), float(y), size=20) for (x, y) in coords]

# %%
keypoints
# Out:
# [< cv2.KeyPoint 0x7fd3c32b6870>,
#  < cv2.KeyPoint 0x7fd3c29ceb10>,
#  < cv2.KeyPoint 0x7fd3c29ce150>,
#  < cv2.KeyPoint 0x7fd3c29cec60>,
#  < cv2.KeyPoint 0x7fd3c29ce4b0>,
#  < cv2.KeyPoint 0x7fd3c29ce240>,
#  < cv2.KeyPoint 0x7fd3c29ceb70>,
#  < cv2.KeyPoint 0x7fd3c29ce6c0>,
#  < cv2.KeyPoint 0x7fd40c5d1810>,
#  < cv2.KeyPoint 0x7fd40c736480>,
#  < cv2.KeyPoint 0x7fd41c032c30>,
#  < cv2.KeyPoint 0x7fd41c1d6ba0>]

# %%
  
# reading image using the imread() function 
imageread = cv2.imread(imgpath) 
  
  
# drawKeypoints function is used to draw keypoints 
output_image = cv2.drawKeypoints(imageread, keypoints, 0, (255, 0, 0), 
                                 flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
  
# displaying the image with keypoints as the 
# output on the screen 
plt.imshow(output_image) 
  
# plotting image 
plt.show()

# %%
imageread
# Out:
# array([[[118, 168, 158],
#         [139, 188, 180],
#         [176, 220, 213],
#         ...,
#         [  0,   1,   5],
#         [  0,   2,   7],
#         [  0,   2,  10]],
#
#        [[ 96, 143, 134],
#         [116, 163, 154],
#         [166, 211, 202],
#         ...,
#         [  0,   1,   5],
#         [  0,   2,   7],
#         [  0,   1,   9]],
#
#        [[113, 159, 147],
#         [105, 153, 141],
#         [145, 191, 179],
#         ...,
#         [  0,   0,   6],
#         [  0,   0,   6],
#         [  0,   0,   8]],
#
#        ...,
#
#        [[245, 217, 230],
#         [244, 216, 229],
#         [244, 214, 227],
#         ...,
#         [212, 194, 207],
#         [215, 197, 210],
#         [216, 197, 212]],
#
#        [[242, 214, 227],
#         [243, 215, 228],
#         [243, 215, 228],
#         ...,
#         [213, 195, 208],
#         [216, 198, 211],
#         [217, 198, 213]],
#
#        [[245, 214, 229],
#         [244, 215, 230],
#         [242, 216, 230],
#         ...,
#         [215, 197, 210],
#         [218, 200, 213],
#         [219, 200, 215]]], dtype=uint8)
